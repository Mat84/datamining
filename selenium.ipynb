# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from selenium) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (3.4.2)
# Requirement already satisfied: requests in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from webdriver-manager) (2.25.1)
# Requirement already satisfied: configparser in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from webdriver-manager) (5.0.2)
# Requirement already satisfied: crayons in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: colorama in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from crayons->webdriver-manager) (0.4.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from requests->webdriver-manager) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from requests->webdriver-manager) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\matteo\miniconda3\envs\webscraping\lib\site-packages (from requests->webdriver-manager) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium.webdriver.common.keys

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.utils import ChromeType
from bs4 import BeautifulSoup

# %%
browser = webdriver.Chrome(ChromeDriverManager(chrome_type=ChromeType.CHROMIUM).install())
# Out:
# ====== WebDriver manager ======
# Current chromium version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Matteo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache

# %%
def login():
    url      = 'https://web.spaggiari.eu/home/app/default/login.php?custcode='
    username = 'BOLS0006.1014599'
    password = 'Agnese1991'
    browser.get(url)
    browser.find_element_by_id('login').send_keys(username)
    browser.find_element_by_id('password').send_keys(password)
    browser.find_element_by_class_name('check-auth').click()

# %%
login()

# %%
url2 = 'https://web.spaggiari.eu/cvv/app/default/gioprof.php?classe_id=&materia=203965&ope=LEZ&codocenza=1&gruppo_id=1AC_RELIGIONE'
browser.get(url2)
browser.find_element_by_class_name('align_middle font_size_14 header headerSortDown').click()

# %%
html = browser.page_source
html
# Out:
# '<html><head>\n\n<title>\nRegistro\n\n\n</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta name="format-detection" content="telephone=no">\n\n\n<link rel="stylesheet" href="../../../commons/css/infoschool.css" type="text/css" media="all">\n<link rel="stylesheet" href="../../css/tic_default.css" type="text/css" media="all">\n<!--<link rel="stylesheet" href="../../../commons/lib/jsx/jQuery/ui/css/is/jquery-ui-1.8.10.custom.css" type="text/css" >-->\n<link rel="stylesheet" href="../../../commons/lib/jsx/jQuery/ui-1.8.23.is12.1/css/is12/jquery-ui-1.8.23.is12.css" type="text/css">\n<link rel="stylesheet" href="../../../commons/lib/jsx/jQuery/ui-1.8.23.is12.1/css/is12/ui-ovr.is12.css" type="text/css">\n\n\n<link rel="stylesheet" href="../../css/themes/base/ui.timepickr.css" type="text/css">\n<link rel="stylesheet" href="../../css/themes/tablesorter/style.css" type="text/css">\n<link rel="stylesheet" href="../../css/themes/tablesorter/jquery.tablesorter.pager.css" type="text/css">\n\n\n\n\n\n\n<iframe src="javascript:void(0)" title="" style="width: 0px; height: 0px; border: 0px; display: none;"></iframe><script type="text/javascript" async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js"></script><script src="../../../commons/lib/jsx/dbg/xdbg-a.js" type="text/javascript"></script>\n<script src="../../../commons/lib/jsx/dbg/xdbg-b.js?v004" type="text/javascript"></script>\n\n<script type="text/javascript" src="../../lib/js/jquery/jquery-1.8.2.min.js"></script>\n<script>\n$$18 = jQuery.noConflict(true);\n</script>\n\n\n<script src="../../../commons/lib/jsx/jQuery/jquery.js" type="text/javascript"></script><script type="text/javascript" src="/commons/lib/jsx/jQuery/plugins/querystring/jquery.querystring.js"></script><script type="text/javascript" src="/commons/lib/jsx/jQuery/external/blockui/jquery.blockUI.js"></script>\n<!--<script src="../../../commons/lib/jsx/jQuery/ui/jquery-ui-1.8.10.custom.min.js" type="text/javascript"></script>-->\n<script src="../../../commons/lib/jsx/jQuery/ui-1.8.23.is12.1/js/jquery-ui-1.8.23.is12.min.js" type="text/javascript"></script>\n<script src="../../../commons/lib/jsx/jQuery/jquery.timers-1.1.2.js" type="text/javascript"></script>\n<script src="../../../commons/lib/jsx/suggerimenti.js" type="text/javascript"></script>\n<script src="../../lib/js/session-ck-alive.js?rev=011" type="text/javascript"></script>\n<script src="../../../commons/lib/jsx/bar.username.js" type="text/javascript"></script>\n\n\n<style>\n\n\ntable.tablesorter tbody td {\nborder: none ;\n}\n\n\n\ntable.dynamic-div { border-collapse:collapse\n}\ntd.cella {\nmargin:0;\nwhite-space:nowrap;\ntext-align:center;\nborder-top:1px solid #cccccc;\nborder-left:1px dotted #cccccc;\n}\ntd.cella_nomedia {\nmargin:0;\nwhite-space:nowrap;\ntext-align:center;\nbackground-color: #0080b8;\ncolor: #ffffff;\nborder:1px solid #cccccc;\n}\ntd.cella_fp {\nmargin:0;\nwhite-space:nowrap;\ntext-align:center;\nbackground-color: #dddddd;\nborder:1px solid #cccccc;\n}\ndiv.tab_cont {\nwidth: 580px;\noverflow-x:scroll;\nmargin-left:260px;\noverflow-y:visible;\npadding-bottom:1px;\n}\n.headcol {\nposition:absolute;\nwidth:247px;\nleft:12px;\ntop:auto;\nmargin-top:-1px; /*compensate for top border*/\n}\n.headcolend {\nposition:absolute;\nheight: 37px;\ncolor:white;\nborder-top:1px solid #cccccc;\nborder-left:1px dotted #cccccc;\ntop:auto;\nmargin-top:-1px; /*compensate for top border*/\n}\n\n.td_testata {\nvertical-align:middle;\ntext-align:center;\npadding-left:1px;\npadding-right:3px;\nborder-top:1px solid #cccccc;\nborder-left:1px dotted #cccccc;\nbackground-color:#FFFFFF;\ncolor: #5C5B5B;\nfont-family: "OpenSans Condensed",arial;\n}\n\n.checkBoxContainer\n{\npadding-left: 35px;\nheight: 28px;\nbackground-repeat: no-repeat;\nbackground-position: left -1px;\nmargin-bottom: 3px;\nmargin-left: 5px;\nline-height: 28px;\ncursor : pointer;\n}\n\n.check_checked {\nbackground-image: url("../../../img/20/Checkbox_Checked.png");\nbac ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
lezioni = soup.find_all("span",{"class":"nota_1"})

# %%
print(lezioni)
# Out:
# [<span class="nota_1">Bilancio dell'anno scolastico e del programma svolto.</span>, <span class="nota_1">Approfondimento sul conflitto tra Israele e Palestina</span>, <span class="nota_1">La figura archetipica del 'trickster'. </span>, <span class="nota_1">Ascolto e commento di una recente testimonianza di Gemma, vedova di Luigi Calabresi: gli anni di piombo, il perdono, la pace del cuore, la differenza tra giustizia e vendetta; continuare ad avere fiducia nell'Istituzione.</span>, <span class="nota_1">Lex orandi e lex credendi. La certezza morale della fede e il rapporto con il dogma.</span>, <span class="nota_1">Discussione sulle radici della fede e sull'essenza del cristianesimo</span>, <span class="nota_1">Gli studi di fra Paolo Benanti: l'algoretica, il transumanesimo, il dataismo e la ricerca di spiritualità dell'homo technologicus</span>, <span class="nota_1">Dalla Cina all'Occidente, indagine sulla privacy e sull'uso dei dati personali.</span>, <span class="nota_1">Cina: pensiero filosofico, gestione del potere e scelte geopolitiche. Il Tao Te Ching e i fondamenti metafisici del principio etico del "wu-wei" ("non agire").</span>, <span class="nota_1">Gli adolescenti ai tempi del Covid pt. 2</span>, <span class="nota_1">Gli adolescenti ai tempi del Covid</span>, <span class="nota_1">Testimonianze di speranza in tempo di Covid</span>, <span class="nota_1">&lt;&lt;Dall'amore non si fugge&gt;&gt;. Mario Ottoboni e l'esperimento delle carceri APAC in Brasile.</span>, <span class="nota_1">Video testimonianza di don Adamo, cappellano del carcere di Piacenza.</span>, <span class="nota_1">Fibonacci, sezione aurea pt. 2</span>, <span class="nota_1">La serie di Fibonacci, la sezione aurea; rappresentazione numerica e grafica dei concetti di 'ordine' e 'armonia'.
# Unità dei saperi scientifici e umanistici.</span>, <span class="nota_1">Il rapporto tra Sapientia e Sacra Scrittura nel Medioevo. I quattro livelli di lettura della Bibbia: "Littera gesta docet, quid credas allegoria, moralis quid agas, quo tendat anagogia"</span>, <span class="nota_1">Scientia et Sapientia nel Medioevo: le artes liberales e la scoperta della struttura intelleggibile del creato secondo Alcuino di York. I fondamenti del progresso scientifico occidentale secondo A. N. Whitehead.</span>, <span class="nota_1">L'attesa</span>, <span class="nota_1">Il dubbio, punto di incontro tra il credente e il non credente.
# materiale per l'approfondimento: Dante, Pd IV,124-132; J. Ratzinger, Introduzione al cristianesimo; W. Pannenberg, Che cosa è l'uomo.</span>, <span class="nota_1">L'amore in rapporto all'eternità. Amare richiede necessariamente un nesso con la totalità? Con l'eternità?</span>, <span class="nota_1">"Vi presento Joe Black" - "come sai che ti ama?" L'amore come cammino di conoscenza.</span>, <span class="nota_1">Il problema dell'amore nel Medioevo: amore di sé e dell'altro. Le due direttrici del problema: confronto tra la concezione fisica o greco-tomista e la concezione estatica dell'amore.
# "Amicabilia quae sunt ad alterum venerunt ex amicalibus quae sunt ad seipsum" Aristotele, Eth. Nic. IX,4</span>, <span class="nota_1">Blasfemia e bestemmia; la legislazione italiana: art. 724 del Cod. Penale; la depenalizzazione della bestemmia ex art. 57, del d.lgs. 30 dicembre 1999, n. 507; il valore delle parole e il valore civile e collettivo delle religioni e del rispetto delle stesse; la decisione del legislatore italiano di accostare il rispetto per la Divinità al rispetto per il culto dei defunti.</span>, <span class="nota_1">Blasfemia e bestemmia; la legislazione italiana (art. 404 del Cod. penale); il valore delle parole; tabù e società.</span>, <span class="nota_1">Simulazione del Parlamento: Civil Law e Common Law; vantaggi e svantaggi dei differenti ordinamenti giuridici. Giusnaturalismo e Positivismo giuridico a confronto.</span>, <span class="nota_1">Simulazione del Parlamento: insediamento della Camera dei deputati e del Senato della Repubblica. Inizio del dibattito in merito agli elementi essenziali di un sistema di governo.</span>, <span class="nota_1">Breve storia di S. Junipero Serra (1713-84), l'umile evangelizzatore della California.
# La schiavitù nel mondo antico: testimonianze e documenti.</span>, <span class="nota_1">Il movimento "Black Lives Matter", la furia iconoclasta e il video virale dell'attivista Curtys Hayes. Analisi e discussione del problema.</span>]

# %%
for j in lezioni
